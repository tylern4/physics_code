# %%
using Pkg
Pkg.add("GR")

using GR
# Out:
#    Updating registry at `/opt/julia/registries/General`
#   Resolving package versions...
# No Changes to `/opt/julia/environments/v1.5/Project.toml`
# No Changes to `/opt/julia/environments/v1.5/Manifest.toml`

# %%
@time begin
    # Create example data
    x = randn(100000)
    y = randn(100000)
    # Draw the hexbin plot
    hexbin(x, y)
end
# Out:
#   0.031092 seconds (250 allocations: 1.892 MiB)
# GR.SVG(UInt8[0x3c, 0x3f, 0x78, 0x6d, 0x6c, 0x20, 0x76, 0x65, 0x72, 0x73  …  0x2f, 0x3e, 0x0a, 0x3c, 0x2f, 0x73, 0x76, 0x67, 0x3e, 0x0a])

# %%
histogram(randn(100000), nbins=100)
# Out:
# GR.SVG(UInt8[0x3c, 0x3f, 0x78, 0x6d, 0x6c, 0x20, 0x76, 0x65, 0x72, 0x73  …  0x2f, 0x3e, 0x0a, 0x3c, 0x2f, 0x73, 0x76, 0x67, 0x3e, 0x0a])
